# %% [markdown]
# #3. 생일이 느린 순서로 10명의 친구를 출력하는 코드

# %%
class Heap:
    def __init__(self, *args):
        if len(args)!=0:
            self.__A=args[0]
        else:
            self.__A=[]

    def insert(self,x):
        self.__A.append(x)
        self.__percolateUp(len(self.__A)-1)

    def __percolateUp(self,i:int):
        parent=(i-1)//2
        if i>0 and self.__A[i]>self.__A[parent]:
            self.__A[i],self.__A[parent]=self.__A[parent],self.__A[i]
            self.__percolateUp(parent)

    def deleteMax(self):
        if (not self.isEmpty()):
            max=self.__A[0]
            self.__A[0]=self.__A.pop()
            self.__percolateDown(0)
            return max
        else:
            return None

    def __percolateDown(self,i:int):
        child=2*i+1
        right=2*i+2
        if (child<=len(self.__A)-1):
            if (right<=len(self.__A)-1 and self.__A[child]<self.__A[right]):
                child=right
            if (self.__A[i]<self.__A[child]):
                self.__A[i],self.__A[child]=self.__A[child],self.__A[i]
                self.__percolateDown(child)

    def max(self):
        return self.__A[0]

    def buildHeap(self):
        for i in range((len(self.__A)-2) // 2,-1,-1):
            self.__percolateDown(i)

    def isEmpty(self)->bool:
        return len(self.__A)==0

    def clear(self):
        self.__A=[]

    def size(self)->int:
        return len(self.__A)

birthdays = [
    (20031015, '강다원'), (20051214, '강민주'), (20041103, '강수아'), (20041108, '강윤서'), (20041228, '강주영'),
    (20041004, '권보은'), (20030805, '김나림'), (20051005, '김나영'), (20040203, '김나현'), (20040117, '김난영'),
    (20000209, '김남은'), (20030304, '김다연'), (20050923, '김도경'), (20051002, '김명신'), (20050324, '김미배'),
    (20051202, '김민경'), (20040210, '김민영'), (20040517, '김민주'), (20041026, '김민주'), (20020911, '김보민'),
    (20040628, '김서빈'), (20050203, '김소민'), (20030110, '김수련'), (20041207, '김수민'), (20030124, '김승연'),
    (20030910, '김시연'), (20031128, '김아린'), (20051031, '김여원'), (20010826, '김연진'), (20051019, '김예빈'),
    (20040412, '김예원'), (20050422, '김정민'), (20000922, '김주영'), (20030110, '김주원'), (20050417, '김주하'),
    (20040722, '김지우'), (20050123, '김채린'), (20050910, '김채민'), (20040409, '김채현'), (20030212, '김하린'),
    (20051001, '김혜인'), (20050501, '김혜정'), (20011212, '김효리'), (20041104, '나주희'), (20050325, '남궁수아'),
    (20050316, '노은서'), (20041105, '두경은'), (20050214, '민고은'), (20040428, '박서연'), (20040514, '박성연'),
    (20040728, '박지호'), (20000507, '박찬미'), (20030603, '박혜린'), (20051102, '배시은'), (20040802, '변수연'),
    (20051024, '서홍빈'), (20030122, '선예영'), (20030104, '성유빈'), (20050620, '손지원'), (20041108, '송민서'),
    (20041206, '신다연'), (20051230, '신수민'), (20040707, '신지예'), (20050126, '신희영'), (20040420, '안소민'),
    (20031022, '안소형'), (20030603, '안수민'), (19851205, '안양준'), (20040501, '안정민'), (20030926, '안희랑'),
    (20030702, '양소윤'), (20051009, '여지혜'), (20020505, '오다현'), (20050328, '오세은'), (20050712, '오예준'),
    (20050509, '오하민'), (20050920, '유채원'), (20050519, '윤서영'), (20040413, '윤소정'), (20030206, '윤여빈'),
    (20050517, '윤혜진'), (20040503, '은유빈'), (20040927, '이가연'), (20041007, '이서연'), (20051112, '이서영'),
    (20051225, '이서영'), (20050305, '이서진'), (20051028, '이서진'), (20040609, '이서현'), (20040118, '이세윤'),
    (20040910, '이수빈'), (20041005, '이승주'), (20010904, '이아현'), (20040316, '이예린'), (20021215, '이예림'),
    (20030109, '이예은'), (20020324, '이우정'), (20050602, '이원진'), (20050601, '이유빈'), (20041107, '이재인'),
    (20030513, '이지후'), (20020415, '이진'), (20040327, '이진서'), (20030516, '이채린'), (20040415, '이희서'),
    (20050207, '임서영'), (20021213, '임성민'), (20040318, '전민서'), (20041121, '정세원'), (20020619, '정승주'),
    (20030802, '정윤서'), (20050224, '정재윤'), (20030917, '정혜민'), (20050119, '조승연'), (20040509, '조예진'),
    (20050926, '주희선'), (20051008, '최가온'), (20050704, '최수안'), (20040805, '한수진'), (20050621, '허재희'),
    (20040611, '홍서연'), (20241282, '홍서연'), (20050203, '홍지연')
]

h=Heap()
for person in birthdays:
    h.insert(person)

print("생일이 느린 순서로 10명:")
for _ in range(10):
    bday,name=h.deleteMax()
    print(f"{name}({bday})")
# Out:
# 생일이 느린 순서로 10명:
# 홍서연(20241282)
# 신수민(20051230)
# 이서영(20051225)
# 강민주(20051214)
# 김민경(20051202)
# 이서영(20051112)
# 배시은(20051102)
# 김여원(20051031)
# 이서진(20051028)
# 서홍빈(20051024)

# %% [markdown]
# #4. 같은 조의 친구들의 이름과 생년월일을 출력하는 코드

# %%
class Birthday:
    def __init__(self,birth,name,group=None):
        self.birth=birth("dummy",None,None)
        self.name=name
        self.group=group

    def __str__(self):
        return f"{self.name} {self.birth}"

class CircularDoublyLinkedList:
    def __init__(self):
        self.__head=BidirectNode("dummy",None,None)
        self.__head.prev=self.__head
        self.__head.next=self.__head
        self.__numItems=0

    def insert(self,i:int,newItem)->None:
        if(i>=0 and i<=self.__numItems):
            prev=self.getNode(i-1)
            newNode=BidirectNode(newItem,None,None)
            newNode.next.prev=newNode
            prev.next=newNode
            self.__numItems+=1
        else:
            print("index",i,":out of bound in insert()")

    def append(self,newItem)->None:
        prev=self.__head.prev
        newNode=BidirectNode(newItem,prev,self.__head)
        prev.next=newNode
        self.__head.prev=newNode
        self.__numItems+=1

    def pop(self, *args):
        if self.isEmpty():
            return None
        if len(args) != 0:
            i = args[0]
        if len(args)==0 or i==-1:
            i = self.__numItems-1
        if (i>=0 and i<=self.__numItems-1):
            curr=self.getNode(i)
            retItem=curr.item
            curr.prev.next=curr.next
            curr.next.prev=curr.prev
            self.__numItems-=1
            return retItem
        else:
            return None

    def remove(self,x):
        curr=self.__findNode(x)
        if curr != None:
            curr.prev.next=curr.next
            curr.next.prev=curr.prev
            self.__numItems-=1
            return x
        else:
            return None

birthdays = [
    (20031015, '강다원'), (20051214, '강민주'), (20041103, '강수아'), (20041108, '강윤서'), (20041228, '강주영'),
    (20041004, '권보은'), (20030805, '김나림'), (20051005, '김나영'), (20040203, '김나현'), (20040117, '김난영'),
    (20000209, '김남은'), (20030304, '김다연'), (20050923, '김도경'), (20051002, '김명신'), (20050324, '김미배'),
    (20051202, '김민경'), (20040210, '김민영'), (20040517, '김민주'), (20041026, '김민주'), (20020911, '김보민'),
    (20040628, '김서빈'), (20050203, '김소민'), (20030110, '김수련'), (20041207, '김수민'), (20030124, '김승연'),
    (20030910, '김시연'), (20031128, '김아린'), (20051031, '김여원'), (20010826, '김연진'), (20051019, '김예빈'),
    (20040412, '김예원'), (20050422, '김정민'), (20000922, '김주영'), (20030110, '김주원'), (20050417, '김주하'),
    (20040722, '김지우'), (20050123, '김채린'), (20050910, '김채민'), (20040409, '김채현'), (20030212, '김하린'),
    (20051001, '김혜인'), (20050501, '김혜정'), (20011212, '김효리'), (20041104, '나주희'), (20050325, '남궁수아'),
    (20050316, '노은서'), (20041105, '두경은'), (20050214, '민고은'), (20040428, '박서연'), (20040514, '박성연'),
    (20040728, '박지호'), (20000507, '박찬미'), (20030603, '박혜린'), (20051102, '배시은'), (20040802, '변수연'),
    (20051024, '서홍빈'), (20030122, '선예영'), (20030104, '성유빈'), (20050620, '손지원'), (20041108, '송민서'),
    (20041206, '신다연'), (20051230, '신수민'), (20040707, '신지예'), (20050126, '신희영'), (20040420, '안소민'),
    (20031022, '안소형'), (20030603, '안수민'), (19851205, '안양준'), (20040501, '안정민'), (20030926, '안희랑'),
    (20030702, '양소윤'), (20051009, '여지혜'), (20020505, '오다현'), (20050328, '오세은'), (20050712, '오예준'),
    (20050509, '오하민'), (20050920, '유채원'), (20050519, '윤서영'), (20040413, '윤소정'), (20030206, '윤여빈'),
    (20050517, '윤혜진'), (20040503, '은유빈'), (20040927, '이가연'), (20041007, '이서연'), (20051112, '이서영'),
    (20051225, '이서영'), (20050305, '이서진'), (20051028, '이서진'), (20040609, '이서현'), (20040118, '이세윤'),
    (20040910, '이수빈'), (20041005, '이승주'), (20010904, '이아현'), (20040316, '이예린'), (20021215, '이예림'),
    (20030109, '이예은'), (20020324, '이우정'), (20050602, '이원진'), (20050601, '이유빈'), (20041107, '이재인'),
    (20030513, '이지후'), (20020415, '이진'), (20040327, '이진서'), (20030516, '이채린'), (20040415, '이희서'),
    (20050207, '임서영'), (20021213, '임성민'), (20040318, '전민서'), (20041121, '정세원'), (20020619, '정승주'),
    (20030802, '정윤서'), (20050224, '정재윤'), (20030917, '정혜민'), (20050119, '조승연'), (20040509, '조예진'),
    (20050926, '주희선'), (20051008, '최가온'), (20050704, '최수안'), (20040805, '한수진'), (20050621, '허재희'),
    (20040611, '홍서연'), (20241282, '홍서연'), (20050203, '홍지연')
]

myGroup=['김연진','변수연','정윤서','박서연','노은서','오세은','박성연','김민경','김보민','홍서연']

for birth, name in birthdays:
    if name in myGroup:
       print(f'{birth} {name}')
# Out:
# 20051202 김민경
# 20020911 김보민
# 20010826 김연진
# 20050316 노은서
# 20040428 박서연
# 20040514 박성연
# 20040802 변수연
# 20050328 오세은
# 20030802 정윤서
# 20040611 홍서연
# 20241282 홍서연

# %% [markdown]
# #5 교재 8장 우선 순위 큐 연습문제

# %% [markdown]
# 1. 있다.
# 2. 그렇다.
# 3. n/2개
# 4. 최악:Θ(nlogn) ,최선:Θ(n)
# 5. 매우 간단
# 6. 비효율적이다. 이 경우, 스며내리기에서 비교가 필요없었던 노드들도 비교해야된다.Θ(n)에서 Θ(nlogn)으로 증가된다.
# 7. 해당 노드를 부모노드와 비교하며 스며오르기를 수행해야한다. 부모보다 크면 값을 교환하고, 더 이상 부모노드보다 크지 않을 때까지 이를 반복한다.

# %% [markdown]
# #6 LeetCode 703.Kth Largest Element in Stream

# %%
from heapq import heappush,heappop

class KthLargest:

    def __init__(self, k: int, nums: List[int]):
        self.min_heap=[]
        self.k=k
        for num in nums:
            self.add(num)

    def add(self, val: int) -> int:
        heappush(self.min_heap,val)
        if len(self.min_heap)>self.k:
            heappop(self.min_heap)
        return self.min_heap[0]
